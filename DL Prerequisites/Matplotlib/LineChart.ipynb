# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.linspace(0, 20, 1000)

# %%
y= np.sin(x) + 0.2 * x

# %%
plt.plot(x,y)

# %%
plt.plot(x,y)
plt.show()

# %%
plt.plot(x,y)
plt.xlabel('input')
plt.ylabel('output')
plt.title('my plot')
# Out:
# Text(0.5, 1.0, 'my plot')

# %%
# above we got this line also: Text(0.5, 1.0, 'my plot')
# to suppress this, use semi colon at the end

plt.plot(x,y)
plt.xlabel('input')
plt.ylabel('output')
plt.title('my plot');
