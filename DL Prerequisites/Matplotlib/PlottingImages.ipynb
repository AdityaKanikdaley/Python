# %%
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image

# %%
im = Image.open('pic.jpg')

# %%
type(im)
# Out:
# PIL.JpegImagePlugin.JpegImageFile

# %%
arr = np.array(im)  # they are integers and between 0 to 255
arr
# Out:
# array([[[  0,  14,  39],
#         [  1,  17,  42],
#         [  5,  21,  46],
#         ...,
#         [ 50, 183, 178],
#         [ 52, 185, 180],
#         [ 54, 187, 182]],
#
#        [[  1,  17,  42],
#         [  2,  18,  43],
#         [  3,  19,  44],
#         ...,
#         [ 46, 179, 174],
#         [ 50, 183, 178],
#         [ 54, 187, 182]],
#
#        [[  3,  19,  44],
#         [  3,  19,  44],
#         [  1,  17,  42],
#         ...,
#         [ 44, 178, 171],
#         [ 48, 182, 175],
#         [ 54, 188, 181]],
#
#        ...,
#
#        [[  1,  16,  39],
#         [  2,  17,  40],
#         [  3,  18,  41],
#         ...,
#         [  7,  23,  48],
#         [  5,  21,  46],
#         [  2,  18,  43]],
#
#        [[  1,  16,  39],
#         [  3,  18,  41],
#         [  5,  20,  43],
#         ...,
#         [  5,  21,  46],
#         [  3,  19,  44],
#         [  1,  17,  42]],
#
#        [[  1,  16,  39],
#         [  4,  19,  42],
#         [  6,  21,  44],
# ...

# %%
arr.shape #its 3D array of size(2160, 3840, 3)
# here 3 represents the RGB colors
# Out:
# (2160, 3840, 3)

# %%
plt.imshow(im)

# %%
plt.imshow(im);

# %%
# take mean across color channels to convert colorfull to greyscale images

gray = arr.mean(axis = 2)
gray.shape
# Out:
# (2160, 3840)

# %%
plt.imshow(gray);

# %%
plt.imshow(gray, cmap='gray');
